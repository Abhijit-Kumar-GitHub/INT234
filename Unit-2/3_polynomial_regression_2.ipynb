# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../DataSets/polynomial.csv")
df
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
X = df.iloc[:, 1:-1]
y = df.iloc[:, -1]
print(X)
print(y)
# Out:
#    Temperature
# 0            0
# 1           20
# 2           40
# 3           60
# 4           80
# 5          100
# 0    0.0002
# 1    0.0012
# 2    0.0060
# 3    0.0300
# 4    0.0900
# 5    0.2700
# Name: Pressure, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
print(X_poly)

lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
# Out:
# [[1.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  [1.000e+00 2.000e+01 4.000e+02 8.000e+03 1.600e+05]
#  [1.000e+00 4.000e+01 1.600e+03 6.400e+04 2.560e+06]
#  [1.000e+00 6.000e+01 3.600e+03 2.160e+05 1.296e+07]
#  [1.000e+00 8.000e+01 6.400e+03 5.120e+05 4.096e+07]
#  [1.000e+00 1.000e+02 1.000e+04 1.000e+06 1.000e+08]]
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X_poly), color = 'blue')
plt.title("polynomial regression")
plt.xlabel("Temperature")
plt.ylabel("Pressure")
# Out:
# Text(0, 0.5, 'Pressure')

# %%
print(lin_reg.predict(poly_reg.fit_transform([[112]])))
# Out:
# [0.47346996]
