# %% [markdown]
# # Day 1 : Data PreProcessing

# %%
import numpy as np
import pandas as pd

# %%
    data = pd.read_csv("../DataSets/ecommerce_customers_unit1.csv")
data

df = data           #for day 2

# %%
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'country', 'signup_date',
#        'last_purchase_date', 'num_orders', 'total_spent', 'avg_order_value',
#        'recency_days', 'is_premium_member', 'device_type',
#        'preferred_category', 'churned'],
#       dtype='object')

# %%
data.shape
# Out:
# (605, 14)

# %%
data.duplicated().sum()

data.drop_duplicates()
# Out:
#      customer_id   age  gender country signup_date last_purchase_date  \
# 0          10001  56.0    Male   India  2022-01-27         2024-04-27
# 1          10002  69.0   Other      UK  2025-01-12         2025-08-01
# 2          10003  46.0  Female     USA  2021-04-25         2021-06-01
# 3          10004  32.0    Male   India  2021-02-23         2023-09-22
# 4          10005  60.0  Female   India  2021-06-07         2021-12-11
# ..           ...   ...     ...     ...         ...                ...
# 595        10596  67.0    Male     USA  2022-12-23         2023-04-28
# 596        10597  62.0  Female   India  2025-02-17         2025-09-27
# 597        10598  28.0    Male     USA  2022-07-12         2025-01-17
# 598        10599  46.0    Male   India  2020-12-01         2024-06-25
# 599        10600  53.0     NaN   India  2021-08-31         2025-08-01
#
#      num_orders  total_spent  avg_order_value  recency_days  \
# 0            10     13273.25          1327.32           522
# ...

# %%
data.shape
# Out:
# (605, 14)

# %%
data.info
# Out:
# <bound method DataFrame.info of      customer_id   age  gender  country signup_date last_purchase_date  \
# 0          10001  56.0    Male    India  2022-01-27         2024-04-27
# 1          10002  69.0   Other       UK  2025-01-12         2025-08-01
# 2          10003  46.0  Female      USA  2021-04-25         2021-06-01
# 3          10004  32.0    Male    India  2021-02-23         2023-09-22
# 4          10005  60.0  Female    India  2021-06-07         2021-12-11
# ..           ...   ...     ...      ...         ...                ...
# 600        10358  25.0  Female    India  2023-09-04         2025-06-18
# 601        10117  50.0    Male      USA  2024-05-11         2024-11-08
# 602        10599  46.0    Male    India  2020-12-01         2024-06-25
# 603        10442  32.0  Female       UK  2023-12-20         2024-09-20
# 604        10555  44.0  Female  Germany  2024-06-16         2024-12-09
#
#      num_orders  total_spent  avg_order_value  recency_days  \
# ...

# %%
data.describe()
# Out:
#         customer_id         age  num_orders    total_spent  avg_order_value  \
# count    605.000000  577.000000  605.000000     571.000000       605.000000
# mean   10301.439669   44.175043    5.945455    8059.212137      1279.377471
# std      173.636071   14.978765    2.332892   10346.781856      1123.841840
# min    10001.000000   18.000000    0.000000       0.000000         0.000000
# 25%    10151.000000   32.000000    4.000000    3920.640000       795.780000
# 50%    10302.000000   45.000000    6.000000    6533.980000      1152.530000
# 75%    10451.000000   56.000000    7.000000    9523.010000      1615.030000
# max    10600.000000   69.000000   13.000000  123891.810000     11431.900000
#
#        recency_days  is_premium_member     churned
# count    605.000000         605.000000  605.000000
# mean     456.029752           0.294215    0.036364
# std      405.810389           0.456066    0.187348
# min        1.000000           0.000000    0.000000
# ...

# %%
data.isnull().sum().sort_values()
# Out:
# customer_id            0
# num_orders             0
# last_purchase_date     0
# signup_date            0
# churned                0
# is_premium_member      0
# recency_days           0
# avg_order_value        0
# preferred_category    22
# age                   28
# device_type           30
# country               32
# total_spent           34
# gender                34
# dtype: int64

# %%
data
# Out:
#      customer_id   age  gender  country signup_date last_purchase_date  \
# 0          10001  56.0    Male    India  2022-01-27         2024-04-27
# 1          10002  69.0   Other       UK  2025-01-12         2025-08-01
# 2          10003  46.0  Female      USA  2021-04-25         2021-06-01
# 3          10004  32.0    Male    India  2021-02-23         2023-09-22
# 4          10005  60.0  Female    India  2021-06-07         2021-12-11
# ..           ...   ...     ...      ...         ...                ...
# 600        10358  25.0  Female    India  2023-09-04         2025-06-18
# 601        10117  50.0    Male      USA  2024-05-11         2024-11-08
# 602        10599  46.0    Male    India  2020-12-01         2024-06-25
# 603        10442  32.0  Female       UK  2023-12-20         2024-09-20
# 604        10555  44.0  Female  Germany  2024-06-16         2024-12-09
#
#      num_orders  total_spent  avg_order_value  recency_days  \
# ...

# %%
# meanAge = data.describe().loc["mean"]['Age']
# meanSalary = data.describe().loc["mean",'Salary']
#
# data['Age'].fillna(meanAge, inplace=True)
# data['Salary'].fillna(meanSalary, inplace=True)
# data

#################as it was for the smaller dataset "Data.csv"

# %%
#find the outliers in the dataset using iqr method

#remove non numeric columns
data_numeric = data.select_dtypes(include=[np.number])

Q1 = data_numeric.quantile(0.25)
Q3 = data_numeric.quantile(0.75)
IQR = Q3 - Q1

# Identifying outliers
outliers = data_numeric[(data_numeric < (Q1 - 1.5 * IQR)) | (data_numeric > (Q3 + 1.5 * IQR))]
outliers
# Out:
#      customer_id  age  num_orders  total_spent  avg_order_value  recency_days  \
# 0            NaN  NaN         NaN          NaN              NaN           NaN
# 1            NaN  NaN         NaN          NaN              NaN           NaN
# 2            NaN  NaN         NaN          NaN              NaN        1583.0
# 3            NaN  NaN         NaN          NaN              NaN           NaN
# 4            NaN  NaN         NaN          NaN              NaN           NaN
# ..           ...  ...         ...          ...              ...           ...
# 600          NaN  NaN         NaN          NaN              NaN           NaN
# 601          NaN  NaN         NaN          NaN              NaN           NaN
# 602          NaN  NaN         NaN          NaN              NaN           NaN
# 603          NaN  NaN         NaN          NaN              NaN           NaN
# 604          NaN  NaN         NaN          NaN              NaN           NaN
#
#      is_premium_member  churned
# ...

# %%
outliers.count()
# Out:
# customer_id           0
# age                   0
# num_orders            5
# total_spent          21
# avg_order_value      15
# recency_days         10
# is_premium_member     0
# churned              22
# dtype: int64

# %%
#outlier using boxplot
import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 6))
# plt.boxplot(data['Age'])
# plt.title('Boxplot for Age')
# plt.show()
#
# plt.figure(figsize=(10, 6))
# plt.boxplot(data['Salary'])
# plt.title('Boxplot for Salary')
# plt.show()


plt.figure(figsize=(10, 6))
plt.boxplot(data_numeric)
plt.title('Boxplot')
plt.show()
